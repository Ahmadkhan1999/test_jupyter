# %% [markdown]
# #              My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Mohd Ahmad

# %% [markdown]
# Student

# %% [markdown]
# *I am Intrested in data Science because I enjoy problem-solving and statistical analysis.*

# %% [markdown]
# ### The following code for the area of Triangle

# %%
base=int(input("enter length of base"))
height=int(input("enter length height "))
area=1/2*(base*height)
print(area)
# Out:
# enter length of base 5
# enter length height  6
# 15.0

# %% [markdown]
# - This is bullet one
# - This is bullet two

# %% [markdown]
# 1. line number one
# 2. line number two

# %% [markdown]
# Use this code and tests all links! [link text](http://url)
#
# [click here to Google](https://www.google.com/)
